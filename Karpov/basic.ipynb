# %%
age = 22

print ('You are ' + str(age) + ' years old')
print ('You are', (age), 'years old')
print (f'You are {age} years old')
# Out:
# You are 22 years old
# You are 22 years old
# You are 22 years old

# %%
# Переобразование типов данных
num = 5.76
print (int(num))

age = '22'
print(f'Age: {int(age) + 1}')

total = 2225.658
print(f'Total revenue: ${int(total)}')
# Out:
# 5
# Age: 23
# Total revenue: $2225

# %%
# Boolean
