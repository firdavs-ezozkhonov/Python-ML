# %%
# В переменных a и b уже записаны длины катетов прямоугольного треугольника. 
# Создайте новую переменную c и сохраните в нее длину гипотенузы этого треугольника. 

a = 3
b = 4

c = (a**2 + b**2)**0.5
print(f'Гипотенуза: {c}')
# Out:
# Гипотенуза: 5.0

# %%
# В переменной father_age хранится возраст отца, а в переменной son_age — возраст сына. 
# Посчитайте, через сколько лет отец будет вдвое старше сына. Результат сохраните в переменную result. 


father_age = 20
son_age = 3
result = 14

father_age = 30.5
son_age = 5.1
result = 20.3


result = father_age - 2 * son_age
print(f'Через {result} лет отец будет вдвое старше сына')
# Out:
# Через 20.3 лет отец будет вдвое старше сына

# %%
# Заданы вещественные числа a, b и с – стороны треугольника. 
# Вычислите периметр и площадь треугольника. Результат сохраните в переменные perimeter
# и area соответственно.


a = 3
b = 4
c = 5

perimeter = a + b + c
p = perimeter / 2
area = (p * (p - a) * (p - b) * (p - c)) ** 0.5

print(f'Периметр: {perimeter}, Площадь: {area}')
# Out:
# Периметр: 12, Площадь: 6.0

# %%
# В переменную n сохранено целое число — количество секунд. Напишите программу, которая 
# конвертирует заданное количество секунд n в часы, минуты и секунды. Результат сохраните в 
# переменные hours, minutes, seconds. То есть сначала нужно посчитать, сколько в число n поместилось 
# целых часов, целых минут и сколько после этого осталось секунд.  


n = 125

hours = 0
minutes = 2
seconds  = 5

hours = n // 3600
minutes = (n % 3600) // 60
seconds = n % 60


print(f'{n} секунд = {hours} часов, {minutes} минут, {seconds} секунд')
# Out:
# 125 секунд = 0 часов, 2 минут, 5 секунд

# %%
# round() - округление числа до указанного количества знаков после запятой.
# abs - модуль числа


num = 345.23
round_num = round(num, 2)
print(round_num)


num = -4.323
abs_num = abs(num)
print(f'Модуль числа {num} = {abs_num}')
# Out:
# 345.23
# Модуль числа -4.323 = 4.323

# %%
# В переменной price_new хранится цена килограмма бананов в числовом формате, а в переменной 
# price_old — цена килограмма бананов год назад. Вычислите, на сколько процентов по модулю изменилась 
# цена за год. Результат сохраните в переменную result. Результат округлите до двух знаков после запятой. 


price_new = 89.99 
price_old = 75.50

delta = abs((price_new - price_old)/price_old * 100)
result = round(delta, 2)

print(f'Цена изменилась на {result}%')
# Out:
# Цена изменилась на 19.19%

# %%
# У тебя зарплата 1234,5678. Округли её до двух знаков после запятой.

salary = 1234.5678
rounded_sal = round(salary, 2)
print(f'Округленная зарплата: {rounded_sal}')


mor = 15.5
even = -3.2 

delta = abs(even - mor)
print(f'Разница между значениями: {delta}')


old_pr = 250.0
new_pr = 199.99

delta = abs((new_pr - old_pr) / old_pr) * 100
result = round(delta, 1)
print(f'Цена изменилась на {result}%')
# Out:
# Округленная зарплата: 1234.57
# Разница между значениями: 18.7
# Цена изменилась на 20.0%

# %%
# В переменную my_sum сохраните сумму трех переменных, которые вы создали, преобразовав значения
# переменных b и с к типу int. Сами переменные b и c изменять не надо.

a = 5
b = '10'
c = True

my_sum = a + int(b) + int(c)
print(f'Сумма: {my_sum}')
# Out:
# Сумма: 16

# %%
age = 21
print('Im ' + str(age) + ' years old')


price = '199'
print (int(price) + 50)

a = '15'
b = 3

print(a + str(b))
print(int(a) + b)
# Out:
# Im 21 years old
# 249
# 153
# 18

# %%
# В переменной a сохранено число с десятичной частью но в формате строки, например '3.14'. 
# В переменную с сохраните целую часть из числа в переменной a.

a = '3.14'
print(int(float(a)))
# Out:
# 6.0
# 3

# %%
# В переменной х уже сохранено целое положительное число. Вычислите 
#  x + x0x0x. Результат сохраните в переменную result.

x = 5
result_1 = x
result_2 =str(x) + '0' + str(x) + '0' + str(x)
print(result_1 + int(result_2))
# Out:
# 50510

# %%
a = 'ИВАН' < 'иван'
b = 'Python' < 'R'
c = 'big number' != 'bug number'
d = 'ЯЯЯ' == 'Я Я'
e = 'игра' >= 'икра'

print(a, b, c, d, e)
# Out:
# True True True False False

# %%
# В переменной m хранится целое положительное число — продолжительность сна в минутах. 
# Если продолжительность сна составит от 7 до 9 часов включительно, то в переменную 
# optimal_sleep_duration сохраните значение True. В противном случае присвойте этой переменной значение False.

m = 500

if m >= 7 * 60 and m <= 9 * 60:    
    optimal_sleep_duration = True
else:
    optimal_sleep_duration = False

print(optimal_sleep_duration)




# В переменной age хранится целое число. Если возраст от 18 до 65 включительно, то is_working_age = True,
# иначе False.

age = 30

if age >=18 and age <= 65:
    is_working_age = True
else:
    is_working_age = False

print(is_working_age)



# В переменной x хранится целое число. Проверьте, делится ли это число без остатка на 3 и на 7. 
# Результат сохраните в переменную result. Переменная result должна иметь логический тип данных. 

x = 7

if x % 3 == 0 and x % 7 == 0:
    result = True
else:
    result = False

print(result)



# Логические операции с числами. 
b = True + 0
print(b)


п = 2 == True
print(п)

e = True ** 0.5
print(e)
# Out:
# True
# True
# False
# 1
# False
# 1.0

# %%
# экранированные последовательности
# \n — перенос строки
# \t — табуляция  
# \' — одинарная кавычка
# \" — двойная кавычка
# \\ — обратный слеш

print("Hello\nWorld")
print("Hello\tWorld")
print('I\'m learning Python')
print("He said, \"Hello, World!\"")
print("This is a backslash: \\")
# Out:
# Hello
# World
# Hello	World
# I'm learning Python
# He said, "Hello, World!"
# This is a backslash: \

# %%
square = '* * * *\n* * * *\n* * * *\n* * * *'
print(square)
